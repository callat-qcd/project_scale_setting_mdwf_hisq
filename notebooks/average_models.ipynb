# %%
import numpy as np
import gvar as gv
import sys
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = [10, 8]

sys.path.append('../')
import fitter.data_loader as dl
import fitter.fit_manager as fm
import fitter.fitter as fit
import fitter.model_average as md

# %%
from importlib import reload
reload(dl)
reload(fm)
reload(fit)
reload(md)
# Out:
# <module 'fitter.model_average' from '../fitter/model_average.py'>

# %%
model_average = md.model_average('2020_11_28-test')
print(model_average)
# Out:
# w0: 0.1708(11)
#
# ---
# Uncertainty:
#    RMS model sdev:   0.00105
#    Model unc:        0.00002
#
# ---
# Error budget (RMS model sdev):
#    Statistical:  0.00091
#    Chiral:       0.00016
#    Disc:         0.00041
#    Phys point:   0.00029
#
# ---
# Highest Weight:
#    0.503:  Fpi_n3lo_log_log2_fv
#    0.497:  Fpi_n3lo_fv
#
# ------
# t0: 0.1708(11)
#
# ---
# Uncertainty:
#    RMS model sdev:   0.00105
#    Model unc:        0.00002
#
# ---
# Error budget (RMS model sdev):
#    Statistical:  0.00091
#    Chiral:       0.00016
#    Disc:         0.00041
#    Phys point:   0.00029
#
# ---
# Highest Weight:
#    0.503:  Fpi_n3lo_log_log2_fv
#    0.497:  Fpi_n3lo_fv
#
# ------

# %%
model_average.plot_fits('l', observable='w0')

# %%
model_average.plot_fits('a', observable='w0')

# %%
model_average.plot_histogram(param='w0')

# %%
model_average.plot_comparison(param='w0')
