# %%
import numpy as np
import gvar as gv
import sys
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = [10, 8]

sys.path.append('../')
import fitter.data_loader as dl
import fitter.fit_manager as fm
import fitter.fitter as fit
import fitter.model_average as md

# %%
from importlib import reload
reload(dl)
reload(fm)
reload(fit)
reload(md)
# Out:
# <module 'fitter.model_average' from '../fitter/model_average.py'>

# %%
model_average = md.model_average('2020_11_22-default_priors')
print(model_average)
# Out:
# w0: 0.1710(12)
#
# ---
# Uncertainty:
#    RMS model sdev:   0.00119
#    Model unc:        0.00024
#
# ---
# Error budget (rms model sdev):
#    Statistical:  0.00093
#    Chiral:       0.00017
#    Disc:         0.00062
#    Phys point:   0.00031
#
# ---
# Highest Weight:
#    0.080:  Fpi_n3lo_log_log2_alphas
#    0.079:  Fpi_n3lo_log_log2
#    0.076:  Fpi_n3lo_log_log2_alphas_fv
#    0.075:  Fpi_n3lo_alphas
#    0.075:  Fpi_n3lo_alphas_fv

# %%
model_average.plot_fits('l')

# %%
model_average.plot_fits('a')

# %%
model_average.plot_histogram()

# %%
model_average.plot_comparison()
