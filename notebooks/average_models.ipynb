# %%
import numpy as np
import gvar as gv
import sys
import matplotlib
import matplotlib.pyplot as plt
#matplotlib.rcParams['figure.figsize'] = [10, 8]

sys.path.append('../')
import fitter.data_loader as dl
import fitter.fit_manager as fm
import fitter.fitter as fit
import fitter.model_average as md

# %%
from importlib import reload
reload(dl)
reload(fm)
reload(fit)
reload(md)
# Out:
# <module 'fitter.model_average' from '/mnt/storage/research/scale-setting/notebooks/../fitter/model_average.py'>

# %%
#model_average = md.model_average('2023_06_20-original_simultaneous')
model_average = md.model_average('2025_03_01-improved_edinburgh')
print(model_average)
# Out:
# {'name': '2025_03_01-improved_edinburgh', 'models': ['Fpi_n2lo_variable', 'Fpi_n2lo_alphas_variable', 'Fpi_n2lo_alphas_fv_variable', 'Fpi_n2lo_fv_variable', 'Fpi_n2lo_log_variable', 'Fpi_n2lo_log_alphas_variable', 'Fpi_n2lo_log_alphas_fv_variable', 'Fpi_n2lo_log_fv_variable', 'Fpi_n3lo_variable', 'Fpi_n3lo_alphas_variable', 'Fpi_n3lo_alphas_fv_variable', 'Fpi_n3lo_fv_variable', 'Fpi_n3lo_log_log2_variable', 'Fpi_n3lo_log_log2_alphas_variable', 'Fpi_n3lo_log_log2_alphas_fv_variable', 'Fpi_n3lo_log_log2_fv_variable', 'Om_n2lo_variable', 'Om_n2lo_alphas_variable', 'Om_n2lo_alphas_fv_variable', 'Om_n2lo_fv_variable', 'Om_n2lo_log_variable', 'Om_n2lo_log_alphas_variable', 'Om_n2lo_log_alphas_fv_variable', 'Om_n2lo_log_fv_variable', 'Om_n3lo_variable', 'Om_n3lo_alphas_variable', 'Om_n3lo_alphas_fv_variable', 'Om_n3lo_fv_variable', 'Om_n3lo_log_log2_variable', 'Om_n3lo_log_log2_alphas_variable', 'Om_n3lo_log_log2_alphas_fv_variable', 'Om_n3lo_log_log2_fv_variable', 'Fpi_n2lo_w0orig', 'Fpi_n
# ...

# %%
#model_average.plot_comparison(observable='t0w0')
model_average.plot_comparison(observable='t0')

# %%
#model_average.plot_histogram(observable='t0w0', compare='latt_ct')
fig = model_average.plot_histogram(observable='w0', compare='eps2a_defn')
fig.tight_layout()
fig.savefig(fname='2.pdf', transparent=True)
fig

# %%
model_average.plot_fits('volume', observable='w0')

# %%
fig = model_average.plot_fits('mpi', observable='w0')
fig
#fig.tight_layout()
#fig.savefig(fname='1.pdf', transparent=True)

# %%
fig = model_average.plot_fits('a', observable='w0')
fig

# %%
import matplotlib as mpl
import matplotlib.patches as mpatches

# %%
fig = model_average.plot_fits('a', observable='t0')
fig
# fig.tight_layout()
# fig.savefig(fname='1.pdf', transparent=True)

# %%
model_average.plot_fits('l', observable='w0')

# %%
model_average.plot_fits('l', observable='t0')

# %%
model_average.plot_histogram(param='w0', observable='w0', compare='eps2a_defn')

# %%
model_average.plot_histogram(param='sqrt_t0', observable='t0', compare='eps2a_defn')

# %%
model_average.plot_comparison(param='w0', observable='w0')

# %%
model_average.plot_comparison(param='sqrt_t0', observable='t0')
