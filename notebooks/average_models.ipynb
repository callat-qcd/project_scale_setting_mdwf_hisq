# %%
import numpy as np
import gvar as gv
import sys
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = [10, 8]

sys.path.append('../')
import fitter.data_loader as dl
import fitter.fit_manager as fm
import fitter.fitter as fit
import fitter.model_average as md

# %%
from importlib import reload
reload(dl)
reload(fm)
reload(fit)
reload(md)
# Out:
# <module 'fitter.model_average' from '/mnt/storage/research/project_scale_setting_mdwf_hisq/notebooks/../fitter/model_average.py'>

# %%
model_average = md.model_average('2020_12_09-improved_variable_w0orig')
print(model_average)
# Out:
# w0: 0.1709(12)
#
# ---
# Uncertainty:
#    RMS model sdev:   0.00114
#    Model unc:        0.00024
#
# ---
# Error budget (RMS model sdev):
#    Statistical:  0.00096
#    Chiral:       0.00017
#    Disc:         0.00050
#    Phys point:   0.00029
#
# ---
# Highest Weight:
#    0.044:  Fpi_n3lo_w0orig
#    0.044:  Fpi_n3lo_fv_w0orig
#    0.043:  Fpi_n3lo_alphas_w0orig
#    0.043:  Fpi_n3lo_alphas_fv_w0orig
#    0.038:  Fpi_n3lo_log_log2_w0orig
#
# ------
# sqrt_t0: 0.1422(11)
#
# ---
# Uncertainty:
#    RMS model sdev:   0.00109
#    Model unc:        0.00012
#
# ---
# Error budget (RMS model sdev):
#    Statistical:  0.00090
#    Chiral:       0.00016
#    Disc:         0.00050
#    Phys point:   0.00025
#
# ---
# Highest Weight:
#    0.044:  Fpi_n3lo_fv_w0orig
#    0.044:  Fpi_n3lo_w0orig
#    0.043:  Fpi_n3lo_alphas_fv_w0orig
#    0.043:  Fpi_n3lo_alphas_w0orig
#    0.038:  Fpi_n3lo_log_log2_w0orig
#
# ------

# %%
model_average.plot_fits('l', observable='w0')

# %%
model_average.plot_fits('l', observable='w0')

# %%
model_average.plot_fits('l', observable='w0')

# %%
model_average.plot_fits('l', observable='t0')

# %%
model_average.plot_histogram(param='w0', observable='w0', compare='eps2a_defn')

# %%
model_average.plot_histogram(param='sqrt_t0', observable='t0', compare='eps2a_defn')

# %%
model_average.plot_comparison(param='w0', observable='w0')

# %%
model_average.plot_comparison(param='sqrt_t0', observable='t0')
